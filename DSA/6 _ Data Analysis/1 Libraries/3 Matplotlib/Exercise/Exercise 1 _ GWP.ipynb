# %% [markdown]
# # GWP = Gross World Product

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [raw]
# Sometimes a relative path is required to avoid errors in VS Code.
# data = pd.read_csv('3 Matplotlib\Data_GWP.csv')

# %%
# But it's not the case with Jupyter.
data = pd.read_csv('Data_GWP.csv')

# %%
data
# Out:
#    Year       GWP
# 0  2014  77868.00
# 1  2010  62220.00
# 2  2005  43070.00
# 3  2000  41016.69
# 4  1995  33644.33
# 5  1990  27539.57
# 6  1985  22481.11
# 7  1980  18818.44
# 8  1975  15149.42
# 9  1970  12137.94

# %%
df = pd.DataFrame(data)

# %%
plt.scatter(df['Year'], df['GWP'])
plt.show()

# %% [markdown]
# # We can make our column as index

# %%
df = df.set_index('Year')

# %%
df['GWP'].plot()
plt.show()

# %% [raw]
# To create a scatter graph this way, we need 2 or more attributes.
# But here we have index 'Year' and only one attribute, 'GWP'.
# So, df['GWP'].scatter() won't work here.
